# %%
from astropy.io import fits
from astropy.table import Table
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats

# %%
filename = 'J0030+0451_merged_phase_0.25-3keV.fits'

hdul = fits.open(filename)

# %%
hdul.info()
# Out:
# Filename: J0030+0451_merged_phase_0.25-3keV.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      44   ()
#   1  EVENTS        1 BinTableHDU   1254   1581519R x 15C   [1D, 1B, 1B, 1I, 1I, 1B, 1B, 8X, 1K, I, J, 1I, 1I, 1E, D]
#   2  GTI           1 BinTableHDU    517   4224R x 2C   [D, D]

# %%
hdul[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   47 / length of dimension 1
# NAXIS2  =              1581519 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                   15 / number of table fields
# EXTNAME = 'EVENTS  '
# HDUCLASS= 'OGIP    '           / Format conforms to OGIP standards
# HDUCLAS1= 'EVENTS  '           / Event extension
# DATAMODE= 'PHOTON  '           / Datamode
# DATE    = '2018-03-08T01:44:54' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# EXPOSURE=              1936256 / [s] Exposure time
# ONTIME  =              1936256 / [s] Sum of stop-start times
# TIMEPIXR=  0.0000000000000E+00 / Bin time beginning=0 middle=0.5 end=1
# TIMEDEL =              40.0E-9 / Data time resolution (40 ns)
# TIMEZERO=                  -1. / Time Zero
# TLMIN2  =                    0 / minimum legal value in the column
# TLMAX2  =                    7 / maximum legal value in the column
# TCRPX2  =                    0 / reference pixel
# TCRVL2  =                  0.0 / reference value
# TCDLT2  =                  1.0 / pixel step value
# TLMIN3  =                    0 / minimum legal value in the column
# TLMAX3  =                    6 / maximum legal value in the column
# TCRPX3  =                    0 / reference pixel
# TCRVL3  =                  0.0 / reference value
# TCDLT3  =                  1.0 / pixel step value
# TLMIN4  =                    0 / minimum legal value in the column
# TLMAX4  =                 4095 / maximum legal value in the column
# TLMIN5  =                    0 / minimum legal value in the column
# TLMAX5  =                 4095 / maximum legal value in the column
# TLMIN7  =             310.1E-9 / [s] minimum legal deadtime
# TLMAX7  =           79075.5E-9 / [s] maximum legal deadtime
# COMMENT   DEADTIME is approximate MPU deadtime on a per-event basis. Each MPU
# COMMENT   is independent of the others.  MPU dead-time is quantized in steps
# COMMENT   of 620.2 ns.  True dead time may be anywhere within this step, but
# COMMENT   this FITS file records the center of the range. The dead-time value is
# COMMENT   truncated at 79075.5 ns; the true dead-time may be larger.
# COMMENT   EVENT_FLAGS is a bit pattern with MPU-derived information flags
# COMMENT   (EVENT_FLAGS == bxx1xxxxx) First X-ray event in an MPU photon packet
# COMMENT   (EVENT_FLAGS == bxxx1xxxx) Slow channel triggered
# COMMENT   (EVENT_FLAGS == bxxxx1xxx) Fast channel triggered
# COMMENT   (EVENT_FLAGS == bxxxxx1xx) Externally triggered pulse height sample
# COMMENT   (EVENT_FLAGS == bxxxxxx1x) Hardware-detected overshoot
# COMMENT   (EVENT_FLAGS == bxxxxxxx1) Hardware-detected undershoot
# COMMENT   $Id: a99ed4d43315e38878d3690ddf900e312cd38ce6 $
# TELESCOP= 'NICER   '           / Telescope (mission) name
# INSTRUME= 'XTI     '           / Instrument name
# TARG_ID =                   50 / NICER target catalog ID number
# OBSERVER= 'GENDREAU, KEITH C.' / Observer or Principal Investigator
# TITLE   = 'LIGHT CURVE MODELING WORKING GROUP' / Science program title
# OBS_ID  = '1060020101'         / Observation ID
# ORIGIN  = 'NASA/GSFC'          / origin of fits file
# CREATOR = 'nicertimecal1 1.5'  / Program that created this FITS file
# TLM2FITS= 'NICER2FITSv1.18_FSWv20170404a' / Telemetry converter version number
# PROCVER = 'l0-master_20180226' / Processing script version number
# SOFTVER = 'Hea_10Oct2017_V6.22.1_NICER_2018-03-01_V003' / HEASoft software versi
# CALDBVER= 'xti20180226'        / CALDB index versions used
# SEQPNUM =                    2 / Number of times the dataset processed
# CHECKSUM= '9dfHGde99deGEde9'   / HDU checksum updated 2019-01-04T10:04:23
# DATASUM = '1979073194'         / data unit checksum updated 2019-01-04T10:04:23
# OBJECT  = 'PSR_J0030+0451'     / Object/target name
# EQUINOX =               2000.0 / [yr] Equinox of celestial coord system
# RADECSYS= 'FK5     '           / celestial coord system
# RA_NOM  =             7.614766 / [deg] R.A. of nominal aspect point [J2000]
# DEC_NOM =             4.861318 / [deg] Dec. of nominal aspect point [J2000]
# RA_OBJ  =             7.614284 / [deg] R.A. of target [J2000]
# DEC_OBJ =             4.861031 / [deg] Dec. of target [J2000]
# TIMESYS = 'TT      '           / Reference time system
# MJDREFI =                56658 /  [d] MJD reference day (2014-01-01T00:00:00)
# MJDREFF = 0.000777592592592593 / [d] MJD reference (fraction of day)
# TIMEREF = 'LOCAL   '           / Reference time location
# TASSIGN = 'SATELLITE'          / Time assigned by clock
# TIMEUNIT= 's       '           / unit for time keywords
# TIERRELA=               1.0E-8 / [s/s] relative errors expressed as rate
# TIERABSO=                  1.0 / [s] timing  precision  in seconds
# TSTART  =            112394325 / [s] time start
# TSTOP   =            155858639 / [s] time stop
# DATE-OBS= '2017-07-24T20:36:00' / Start date of observations
# DATE-END= '2017-07-24T23:59:20' / End date of observations
# CLOCKAPP=                    T / Clock correction has been applied
# DEADAPP =                    F / Has DEADC been applied to data?
# LEAPINIT=                    2 / [s] Leap seconds between MJDREF and TSTART
# MPUTICKR=            25803540. / [Hz] Nominal MPU tick rate (custom)
# MPUTICKM= 'PREVIOUS'           / Use previous PPS to adjust MPU tick rate
# MPUTIMEM= 'PREVIOUS'           / Extraplate MPU time from previous PPS
# MPU_ID  =                    0 /  Selected MPU number
# HISTORY
# HISTORY START PARAMETER list for nicerpi_interp_1.2 at 2018-12-16T00:01:18
# HISTORY
# HISTORY P1 infile = PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_0mpu0_uf
# HISTORY P1 a.evt_filt
# HISTORY P2 outfile = PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_0mpu0_u
# HISTORY P2 fa.evt_fastcal.interp
# HISTORY P3 hkfile = PSR_J0030+0451/1060020101/xti/hk/ni1060020101_0mpu0.hk
# HISTORY P4 columns = MPU_A_TEMP,MPU_UNDER_COUNT
# HISTORY P5 existpolicy = OVERWRITE
# HISTORY P6 timeoffset = -0.5
# HISTORY P7 clobber = YES
# HISTORY P8 chatter = 0
# HISTORY P9 history = YES
# HISTORY P10 mode = ql
# HISTORY END PARAMETER list for nicerpi_interp_1.2
# HISTORY
# TLMIN12 =                  -10 / Minimum legal value
# TLMAX12 =                 1800 / Maximum legal value
# GAINAPP =                    T / Gain correction has been applied
# LONGSTRN= 'OGIP 1.0'           / The HEASARC Long String Convention may be used.
# COMMENT   This FITS file may contain long string keyword values that are
# COMMENT   continued over multiple keywords.  The HEASARC convention uses the &
# COMMENT   character at the end of each substring which is then continued
# COMMENT   on the next keyword which has the name CONTINUE.
# GAINMETH= 'FT_OFF+MPU(PULSE_GRID)+MPUPIN(MPU_A_TEMP(POLY),MPU_UNDER_COUNT(DARK&'
# CONTINUE  '_MV),MV_TREND)+ECORR(UNDER_GAIN)' / MPU pulse grid lookup + FPM linea
# GCALFILE= 'nixtiflightpi20170601v002.fits[1]' / Gain calibration file name
# HISTORY
# HISTORY START PARAMETER list for nicerpi1_1.21 at 2018-12-16T00:01:18
# HISTORY
# HISTORY P1 infile = PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_0mpu0_uf
# HISTORY P1 a.evt_fastcal.interp
# HISTORY P2 calfile = /Software/CALDB/CALDB/data/nicer/xti/bcf/gainfast/nixtiflig
# HISTORY P2 htpifast20170601v001.fits[1]
# HISTORY P3 outfile = PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_0mpu0_u
# HISTORY P3 fa.evt_fastcal
# HISTORY P4 column = PI_FAST
# HISTORY P5 energycolumn = NONE
# HISTORY P6 initialize = YES
# HISTORY P7 pigain = 0.010
# HISTORY P8 pioffset = 0.000
# HISTORY P9 auxcolumns = MPU_A_TEMP,MPU_UNDER_COUNT
# HISTORY P10 randomize = YES
# HISTORY P11 randomseed = 0
# HISTORY P12 clobber = YES
# HISTORY P13 chatter = 0
# HISTORY P14 history = YES
# HISTORY P15 mode = ql
# HISTORY END PARAMETER list for nicerpi1_1.21
# HISTORY
# HISTORY
# HISTORY START PARAMETER list for nicerpi_interp_1.2 at 2018-12-16T00:01:18
# HISTORY
# HISTORY P1 infile = PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_0mpu0_uf
# HISTORY P1 a.evt_fastcal
# HISTORY P2 outfile = PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_0mpu0_u
# HISTORY P2 fa.evt_slowcal.interp
# HISTORY P3 hkfile = PSR_J0030+0451/1060020101/xti/hk/ni1060020101_0mpu0.hk
# HISTORY P4 columns = MPU_A_TEMP,MPU_UNDER_COUNT,TIME
# HISTORY P5 existpolicy = KEEP
# HISTORY P6 timeoffset = -0.5
# HISTORY P7 clobber = YES
# HISTORY P8 chatter = 0
# HISTORY P9 history = YES
# HISTORY P10 mode = ql
# HISTORY END PARAMETER list for nicerpi_interp_1.2
# HISTORY
# TLMIN13 =                    0
# TLMAX13 =                 1500
# HISTORY
# HISTORY START PARAMETER list for nicerpi1_1.21 at 2018-12-16T00:01:18
# HISTORY
# HISTORY P1 infile = PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_0mpu0_uf
# HISTORY P1 a.evt_slowcal.interp
# HISTORY P2 calfile = /Software/CALDB/CALDB/data/nicer/xti/bcf/gain/nixtiflightpi
# HISTORY P2 20170601v002.fits[1]
# HISTORY P3 outfile = PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_0mpu0_u
# HISTORY P3 fa.evt_slowcal
# HISTORY P4 column = PI
# HISTORY P5 energycolumn = NONE
# HISTORY P6 initialize = YES
# HISTORY P7 pigain = 0.010
# HISTORY P8 pioffset = 0.000
# HISTORY P9 auxcolumns = MPU_A_TEMP,MPU_UNDER_COUNT,TIME
# HISTORY P10 randomize = YES
# HISTORY P11 randomseed = 0
# HISTORY P12 clobber = YES
# HISTORY P13 chatter = 0
# HISTORY P14 history = YES
# HISTORY P15 mode = ql
# HISTORY END PARAMETER list for nicerpi1_1.21
# HISTORY
# TIMEMETH= 'MPU(CONST)+TIMEZERO(-1)' / Constant MPU bias + Broadreach
# TCALFILE= 'nixtitimebias20150901v003.fits[1]' / TIME calibration file name
# HISTORY
# HISTORY START PARAMETER list for nicertimecal1_1.5 at 2018-12-16T00:01:19
# HISTORY
# HISTORY P1 infile = PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_0mpu0_uf
# HISTORY P1 a.evt_slowcal
# HISTORY P2 calfile = /Software/CALDB/CALDB/data/nicer/xti/bcf/timebias/nixtitime
# HISTORY P2 bias20150901v003.fits[1]
# HISTORY P3 outfile = PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_0mpu0_u
# HISTORY P3 fa.evt_timecal
# HISTORY P4 auxcolumns = NONE
# HISTORY P5 clobber = YES
# HISTORY P6 chatter = 0
# HISTORY P7 history = YES
# HISTORY P8 mode = ql
# HISTORY END PARAMETER list for nicertimecal1_1.5
# HISTORY
# HISTORY CFITSIO used the following filtering expression to create this table:
# HISTORY PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_0mpu0_ufa.evt[EVENTS
# HISTORY ][(gtifilter("PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_0mpu7_
# HISTORY ufa.evt_unsort-evgti.gti",TIME))]
# HISTORY
# HISTORY START PARAMETER list for ftmerge_2.20 at 2018-12-16T00:01:27
# HISTORY
# HISTORY P1 (infile = @PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_0mpu7_
# HISTORY P1 ufa.evt_unsort-events.lis)
# HISTORY
# HISTORY START FILE listing: ni1060020101_0mpu7_ufa.evt_unsort-events.lis
# HISTORY
# HISTORY F1 PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_0mpu0_ufa.evt[EVE
# HISTORY F1 NTS][(gtifilter("PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_
# HISTORY F1 u7_ufa.evt_unsort-evgti.gti",TIME))]
# HISTORY F2 PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_0mpu1_ufa.evt[EVE
# HISTORY F2 NTS][(gtifilter("PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_
# HISTORY F2 u7_ufa.evt_unsort-evgti.gti",TIME))]
# HISTORY F3 PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_0mpu2_ufa.evt[EVE
# HISTORY F3 NTS][(gtifilter("PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_
# HISTORY F3 u7_ufa.evt_unsort-evgti.gti",TIME))]
# HISTORY F4 PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_0mpu3_ufa.evt[EVE
# HISTORY F4 NTS][(gtifilter("PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_
# HISTORY F4 u7_ufa.evt_unsort-evgti.gti",TIME))]
# HISTORY F5 PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_0mpu4_ufa.evt[EVE
# HISTORY F5 NTS][(gtifilter("PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_
# HISTORY F5 u7_ufa.evt_unsort-evgti.gti",TIME))]
# HISTORY F6 PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_0mpu5_ufa.evt[EVE
# HISTORY F6 NTS][(gtifilter("PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_
# HISTORY F6 u7_ufa.evt_unsort-evgti.gti",TIME))]
# HISTORY F7 PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_0mpu6_ufa.evt[EVE
# HISTORY F7 NTS][(gtifilter("PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_
# HISTORY F7 u7_ufa.evt_unsort-evgti.gti",TIME))]
# HISTORY END FILE listing: ni1060020101_0mpu7_ufa.evt_unsort-events.lis
# HISTORY
# HISTORY P2 outfile = PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_0mpu7_u
# HISTORY P2 fa.evt_unsort
# HISTORY P3 columns = *
# HISTORY P4 insertrow = 0
# HISTORY P5 lastkey =
# HISTORY P6 copyall = YES
# HISTORY P7 skipbadfiles = NO
# HISTORY P8 clobber = YES
# HISTORY P9 chatter = 1
# HISTORY P10 history = YES
# HISTORY P11 mode = ql
# HISTORY END PARAMETER list for ftmerge_2.20
# HISTORY
# TELAPSE =              1936256 / [s] total elapsed time
# HISTORY CFITSIO used the following filtering expression to create this table:
# HISTORY PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_0mpu7_ufa.evt[EVENTS
# HISTORY ][(((PI >= 20)&&(PI <= 1500)&&(EVENT_FLAGS == bx1x000)&&((DEFNULL(PI_RAT
# HISTORY IO,1)<1.100000+120.000000/PI+0.000000e+00*PI**4)))&&gtifilter("PSR_J0030
# HISTORY +0451/1060020101/xti/event_cl/ni1060020101_0mpu7_cl.evt-totgti.gti",TIME
# HISTORY ))]
# HISTORY
# HISTORY START PARAMETER list for ftmerge_2.20 at 2018-12-16T00:01:29
# HISTORY
# HISTORY P1 (infile = @PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_0mpu7_
# HISTORY P1 cl.evt-events.lis)
# HISTORY
# HISTORY START FILE listing: ni1060020101_0mpu7_cl.evt-events.lis
# HISTORY
# HISTORY F1 PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_0mpu7_ufa.evt[EVE
# HISTORY F1 NTS][(((PI >= 20)&&(PI <= 1500)&&(EVENT_FLAGS == bx1x000)&&((DEFNULL(
# HISTORY F1 RATIO,1)<1.100000+120.000000/PI+0.000000e+00*PI**4)))&&gtifilter("PSR
# HISTORY F1 030+0451/1060020101/xti/event_cl/ni1060020101_0mpu7_cl.evt-totgti.gti
# HISTORY F1 IME))]
# HISTORY END FILE listing: ni1060020101_0mpu7_cl.evt-events.lis
# HISTORY
# HISTORY P2 outfile = PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101_0mpu7_c
# HISTORY P2 l.evt
# HISTORY P3 columns = *
# HISTORY P4 insertrow = 0
# HISTORY P5 lastkey =
# HISTORY P6 copyall = YES
# HISTORY P7 skipbadfiles = NO
# HISTORY P8 clobber = YES
# HISTORY P9 chatter = 1
# HISTORY P10 history = YES
# HISTORY P11 mode = ql
# HISTORY END PARAMETER list for ftmerge_2.20
# HISTORY
# HISTORY CFITSIO used the following filtering expression to create this table:
# HISTORY /Scratch6/NICER/data/PSR_J0030+0451/1060020101/xti/event_cl/ni1060020101
# HISTORY _0mpu7_cl.evt[EVENTS][(((PI >= 25)&&(PI <= 800)&&(EVENT_FLAGS == bx1x000
# HISTORY ))&&gtifilter("1060020101_pipe/intermediate.evt-totgti.gti",TIME))]
# HISTORY
# HISTORY START PARAMETER list for ftmerge_2.20 at 2019-01-04T15:03:59
# HISTORY
# HISTORY P1 (infile = @1060020101_pipe/intermediate.evt-events.lis)
# HISTORY
# HISTORY START FILE listing: intermediate.evt-events.lis
# HISTORY
# HISTORY F1 /Scratch6/NICER/data/PSR_J0030+0451/1060020101/xti/event_cl/ni1060020
# HISTORY F1 101_0mpu7_cl.evt[EVENTS][(((PI >= 25)&&(PI <= 800)&&(EVENT_FLAGS == b
# HISTORY F1 000))&&gtifilter("1060020101_pipe/intermediate.evt-totgti.gti",TIME))
# HISTORY END FILE listing: intermediate.evt-events.lis
# HISTORY
# HISTORY P2 outfile = 1060020101_pipe/intermediate.evt
# HISTORY P3 columns = *
# HISTORY P4 insertrow = 0
# HISTORY P5 lastkey =
# HISTORY P6 copyall = YES
# HISTORY P7 skipbadfiles = NO
# HISTORY P8 clobber = YES
# HISTORY P9 chatter = 1
# HISTORY P10 history = YES
# HISTORY P11 mode = ql
# HISTORY END PARAMETER list for ftmerge_2.20
# HISTORY
# TTYPE1  = 'TIME    '
# TFORM1  = '1D      '
# TUNIT1  = 's       '
# TDISP1  = 'F20.9   '
# TTYPE2  = 'RAWX    '
# TFORM2  = '1B      '
# TUNIT2  = 'pixel   '
# TTYPE3  = 'RAWY    '
# TFORM3  = '1B      '
# TUNIT3  = 'pixel   '
# TTYPE4  = 'PHA     '
# TFORM4  = '1I      '
# TUNIT4  = 'chan    '
# TNULL4  =               -32768
# TTYPE5  = 'PHA_FAST'
# TFORM5  = '1I      '
# TUNIT5  = 'chan    '
# TNULL5  =               -32768
# TTYPE6  = 'DET_ID  '
# TFORM6  = '1B      '
# TDISP6  = 'I2.2    '
# TTYPE7  = 'DEADTIME'
# TFORM7  = '1B      '
# TUNIT7  = 's       '
# TSCAL7  =            6.202E-07
# TZERO7  =            3.101E-07
# TDISP7  = 'F11.9   '
# TTYPE8  = 'EVENT_FLAGS'
# TFORM8  = '8X      '
# TTYPE9  = 'TICK    '
# TFORM9  = '1K      '
# TTYPE10 = 'MPU_A_TEMP'
# TFORM10 = 'I       '
# TUNIT10 = 'Celsius '
# TNULL10 =                   -1
# TSCAL10 =           0.10600843
# TZERO10 =           -273.42105
# TDISP10 = 'F6.3    '
# TTYPE11 = 'MPU_UNDER_COUNT'
# TFORM11 = 'J       '
# TNULL11 =                   -1
# TTYPE12 = 'PI_FAST '
# TFORM12 = '1I      '
# TUNIT12 = 'chan    '
# TNULL12 =               -32768
# TTYPE13 = 'PI      '
# TFORM13 = '1I      '
# TUNIT13 = 'chan    '
# TNULL13 =               -32768
# TTYPE14 = 'PI_RATIO'
# TFORM14 = '1E      '
# TTYPE15 = 'PULSE_PHASE'
# TFORM15 = 'D       '
# HISTORY CFITSIO used the following filtering expression to create this table:
# HISTORY 1060020101_pipe/intermediate.evt[(EVENT_FLAGS==bx1x000).and.(DET_ID!=14)
# HISTORY .and.(DET_ID!=34).and.(DET_ID!=54)]
# HISTORY CFITSIO used the following filtering expression to create this table:
# HISTORY cleanfilt.evt[EVENTS][(gtifilter("cleanfilt_cut.evt-totgti.gti",TIME))]
# HISTORY
# HISTORY START PARAMETER list for ftmerge_2.20 at 2019-01-04T20:58:10
# HISTORY
# HISTORY P1 (infile = @cleanfilt_cut.evt-events.lis)
# HISTORY
# HISTORY START FILE listing: cleanfilt_cut.evt-events.lis
# HISTORY
# HISTORY F1 cleanfilt.evt[EVENTS][(gtifilter("cleanfilt_cut.evt-totgti.gti",TIME)
# HISTORY F1 )]
# HISTORY END FILE listing: cleanfilt_cut.evt-events.lis
# HISTORY
# HISTORY P2 outfile = cleanfilt_cut.evt
# HISTORY P3 columns = *
# HISTORY P4 insertrow = 0
# HISTORY P5 lastkey =
# HISTORY P6 copyall = YES
# HISTORY P7 skipbadfiles = NO
# HISTORY P8 clobber = YES
# HISTORY P9 chatter = 1
# HISTORY P10 history = YES
# HISTORY P11 mode = ql
# HISTORY END PARAMETER list for ftmerge_2.20
# HISTORY
# HISTORY CFITSIO used the following filtering expression to create this table:
# HISTORY 1060020101_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evgti.g
# HISTORY ti",TIME))]
# HISTORY
# HISTORY START PARAMETER list for ftmerge_2.20 at 2019-01-16T19:02:52
# HISTORY
# HISTORY P1 (infile = @merged.evt-events.lis)
# HISTORY
# HISTORY START FILE listing: merged.evt-events.lis
# HISTORY
# HISTORY F1 1060020101_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evgt
# HISTORY F1 i.gti",TIME))]
# HISTORY F2 1060020102_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evgt
# HISTORY F2 i.gti",TIME))]
# HISTORY F3 1060020103_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evgt
# HISTORY F3 i.gti",TIME))]
# HISTORY F4 1060020104_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evgt
# HISTORY F4 i.gti",TIME))]
# HISTORY F5 1060020105_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evgt
# HISTORY F5 i.gti",TIME))]
# HISTORY F6 1060020106_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evgt
# HISTORY F6 i.gti",TIME))]
# HISTORY F7 1060020107_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evgt
# HISTORY F7 i.gti",TIME))]
# HISTORY F8 1060020108_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evgt
# HISTORY F8 i.gti",TIME))]
# HISTORY F9 1060020109_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evgt
# HISTORY F9 i.gti",TIME))]
# HISTORY F10 1060020110_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F10 ti.gti",TIME))]
# HISTORY F11 1060020111_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F11 ti.gti",TIME))]
# HISTORY F12 1060020112_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F12 ti.gti",TIME))]
# HISTORY F13 1060020113_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F13 ti.gti",TIME))]
# HISTORY F14 1060020114_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F14 ti.gti",TIME))]
# HISTORY F15 1060020115_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F15 ti.gti",TIME))]
# HISTORY F16 1060020116_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F16 ti.gti",TIME))]
# HISTORY F17 1060020117_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F17 ti.gti",TIME))]
# HISTORY F18 1060020118_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F18 ti.gti",TIME))]
# HISTORY F19 1060020119_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F19 ti.gti",TIME))]
# HISTORY F20 1060020120_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F20 ti.gti",TIME))]
# HISTORY F21 1060020121_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F21 ti.gti",TIME))]
# HISTORY F22 1060020122_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F22 ti.gti",TIME))]
# HISTORY F23 1060020123_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F23 ti.gti",TIME))]
# HISTORY F24 1060020124_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F24 ti.gti",TIME))]
# HISTORY F25 1060020125_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F25 ti.gti",TIME))]
# HISTORY F26 1060020126_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F26 ti.gti",TIME))]
# HISTORY F27 1060020127_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F27 ti.gti",TIME))]
# HISTORY F28 1060020128_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F28 ti.gti",TIME))]
# HISTORY F29 1060020129_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F29 ti.gti",TIME))]
# HISTORY F30 1060020130_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F30 ti.gti",TIME))]
# HISTORY F31 1060020131_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F31 ti.gti",TIME))]
# HISTORY F32 1060020132_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F32 ti.gti",TIME))]
# HISTORY F33 1060020133_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F33 ti.gti",TIME))]
# HISTORY F34 1060020134_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F34 ti.gti",TIME))]
# HISTORY F35 1060020135_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F35 ti.gti",TIME))]
# HISTORY F36 1060020136_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F36 ti.gti",TIME))]
# HISTORY F37 1060020137_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F37 ti.gti",TIME))]
# HISTORY F38 1060020138_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F38 ti.gti",TIME))]
# HISTORY F39 1060020139_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F39 ti.gti",TIME))]
# HISTORY F40 1060020140_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F40 ti.gti",TIME))]
# HISTORY F41 1060020141_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F41 ti.gti",TIME))]
# HISTORY F42 1060020142_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F42 ti.gti",TIME))]
# HISTORY F43 1060020143_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F43 ti.gti",TIME))]
# HISTORY F44 1060020144_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F44 ti.gti",TIME))]
# HISTORY F45 1060020145_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F45 ti.gti",TIME))]
# HISTORY F46 1060020146_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F46 ti.gti",TIME))]
# HISTORY F47 1060020147_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F47 ti.gti",TIME))]
# HISTORY F48 1060020148_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F48 ti.gti",TIME))]
# HISTORY F49 1060020149_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F49 ti.gti",TIME))]
# HISTORY F50 1060020150_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F50 ti.gti",TIME))]
# HISTORY F51 1060020151_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F51 ti.gti",TIME))]
# HISTORY F52 1060020152_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F52 ti.gti",TIME))]
# HISTORY F53 1060020153_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F53 ti.gti",TIME))]
# HISTORY F54 1060020154_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F54 ti.gti",TIME))]
# HISTORY F55 1060020156_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F55 ti.gti",TIME))]
# HISTORY F56 1060020157_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F56 ti.gti",TIME))]
# HISTORY F57 1060020158_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F57 ti.gti",TIME))]
# HISTORY F58 1060020159_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F58 ti.gti",TIME))]
# HISTORY F59 1060020160_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F59 ti.gti",TIME))]
# HISTORY F60 1060020161_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F60 ti.gti",TIME))]
# HISTORY F61 1060020162_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F61 ti.gti",TIME))]
# HISTORY F62 1060020163_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F62 ti.gti",TIME))]
# HISTORY F63 1060020164_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F63 ti.gti",TIME))]
# HISTORY F64 1060020165_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F64 ti.gti",TIME))]
# HISTORY F65 1060020166_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F65 ti.gti",TIME))]
# HISTORY F66 1060020167_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F66 ti.gti",TIME))]
# HISTORY F67 1060020168_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F67 ti.gti",TIME))]
# HISTORY F68 1060020169_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F68 ti.gti",TIME))]
# HISTORY F69 1060020170_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F69 ti.gti",TIME))]
# HISTORY F70 1060020171_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F70 ti.gti",TIME))]
# HISTORY F71 1060020172_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F71 ti.gti",TIME))]
# HISTORY F72 1060020173_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F72 ti.gti",TIME))]
# HISTORY F73 1060020174_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F73 ti.gti",TIME))]
# HISTORY F74 1060020175_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F74 ti.gti",TIME))]
# HISTORY F75 1060020176_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F75 ti.gti",TIME))]
# HISTORY F76 1060020177_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F76 ti.gti",TIME))]
# HISTORY F77 1060020178_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F77 ti.gti",TIME))]
# HISTORY F78 1060020179_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F78 ti.gti",TIME))]
# HISTORY F79 1060020180_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F79 ti.gti",TIME))]
# HISTORY F80 1060020181_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F80 ti.gti",TIME))]
# HISTORY F81 1060020182_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F81 ti.gti",TIME))]
# HISTORY F82 1060020183_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F82 ti.gti",TIME))]
# HISTORY F83 1060020184_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F83 ti.gti",TIME))]
# HISTORY F84 1060020185_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F84 ti.gti",TIME))]
# HISTORY F85 1060020186_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F85 ti.gti",TIME))]
# HISTORY F86 1060020187_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F86 ti.gti",TIME))]
# HISTORY F87 1060020188_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F87 ti.gti",TIME))]
# HISTORY F88 1060020189_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F88 ti.gti",TIME))]
# HISTORY F89 1060020190_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F89 ti.gti",TIME))]
# HISTORY F90 1060020191_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F90 ti.gti",TIME))]
# HISTORY F91 1060020192_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F91 ti.gti",TIME))]
# HISTORY F92 1060020193_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F92 ti.gti",TIME))]
# HISTORY F93 1060020194_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F93 ti.gti",TIME))]
# HISTORY F94 1060020195_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F94 ti.gti",TIME))]
# HISTORY F95 1060020196_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# HISTORY F95 ti.gti",TIME))]
# HISTORY F96 1060020197_pipe/cleanfilt_cut.evt[EVENTS][(gtifilter("merged.evt-evg
# ...
# FILIN085= 'cleanfilt_cut.evt'
# FILIN086= 'cleanfilt_cut.evt'
# FILIN087= 'cleanfilt_cut.evt'
# FILIN088= 'cleanfilt_cut.evt'
# FILIN089= 'cleanfilt_cut.evt'
# FILIN090= 'cleanfilt_cut.evt'
# FILIN091= 'cleanfilt_cut.evt'
# FILIN092= 'cleanfilt_cut.evt'
# FILIN093= 'cleanfilt_cut.evt'
# FILIN094= 'cleanfilt_cut.evt'
# FILIN095= 'cleanfilt_cut.evt'
# FILIN096= 'cleanfilt_cut.evt'
# FILIN097= 'cleanfilt_cut.evt'
# FILIN098= 'cleanfilt_cut.evt'
# FILIN099= 'cleanfilt_cut.evt'
# FILIN100= 'cleanfilt_cut.evt'
# FILIN101= 'cleanfilt_cut.evt'
# FILIN102= 'cleanfilt_cut.evt'
# FILIN103= 'cleanfilt_cut.evt'
# FILIN104= 'cleanfilt_cut.evt'
# FILIN105= 'cleanfilt_cut.evt'
# FILIN106= 'cleanfilt_cut.evt'
# FILIN107= 'cleanfilt_cut.evt'
# FILIN108= 'cleanfilt_cut.evt'
# FILIN109= 'cleanfilt_cut.evt'
# FILIN110= 'cleanfilt_cut.evt'
# FILIN111= 'cleanfilt_cut.evt'
# FILIN112= 'cleanfilt_cut.evt'
# FILIN113= 'cleanfilt_cut.evt'
# FILIN114= 'cleanfilt_cut.evt'
# FILIN115= 'cleanfilt_cut.evt'
# FILIN116= 'cleanfilt_cut.evt'
# FILIN117= 'cleanfilt_cut.evt'
# FILIN118= 'cleanfilt_cut.evt'
# FILIN119= 'cleanfilt_cut.evt'
# FILIN120= 'cleanfilt_cut.evt'
# FILIN121= 'cleanfilt_cut.evt'
# FILIN122= 'cleanfilt_cut.evt'
# FILIN123= 'cleanfilt_cut.evt'
# FILIN124= 'cleanfilt_cut.evt'
# FILIN125= 'cleanfilt_cut.evt'
# FILIN126= 'cleanfilt_cut.evt'
# FILIN127= 'cleanfilt_cut.evt'
# FILIN128= 'cleanfilt_cut.evt'
# FILIN129= 'cleanfilt_cut.evt'
# FILIN130= 'cleanfilt_cut.evt'
# FILIN131= 'cleanfilt_cut.evt'
# FILIN132= 'cleanfilt_cut.evt'
# FILIN133= 'cleanfilt_cut.evt'
# FILIN134= 'cleanfilt_cut.evt'
# FILIN135= 'cleanfilt_cut.evt'
# FILIN136= 'cleanfilt_cut.evt'
# FILIN137= 'cleanfilt_cut.evt'
# FILIN138= 'cleanfilt_cut.evt'
# FILIN139= 'cleanfilt_cut.evt'
# FILIN140= 'cleanfilt_cut.evt'
# FILIN141= 'cleanfilt_cut.evt'
# FILIN142= 'cleanfilt_cut.evt'
# FILIN143= 'cleanfilt_cut.evt'
# FILIN144= 'cleanfilt_cut.evt'
# FILIN145= 'cleanfilt_cut.evt'
# FILIN146= 'cleanfilt_cut.evt'
# FILIN147= 'cleanfilt_cut.evt'
# FILIN148= 'cleanfilt_cut.evt'
# FILIN149= 'cleanfilt_cut.evt'
# FILIN150= 'cleanfilt_cut.evt'
# FILIN151= 'cleanfilt_cut.evt'
# FILIN152= 'cleanfilt_cut.evt'
# FILIN153= 'cleanfilt_cut.evt'
# FILIN154= 'cleanfilt_cut.evt'
# FILIN155= 'cleanfilt_cut.evt'
# FILIN156= 'cleanfilt_cut.evt'
# FILIN157= 'cleanfilt_cut.evt'
# FILIN158= 'cleanfilt_cut.evt'
# FILIN159= 'cleanfilt_cut.evt'
# FILIN160= 'cleanfilt_cut.evt'
# FILIN161= 'cleanfilt_cut.evt'
# FILIN162= 'cleanfilt_cut.evt'
# FILIN163= 'cleanfilt_cut.evt'
# FILIN164= 'cleanfilt_cut.evt'
# FILIN165= 'cleanfilt_cut.evt'
# FILIN166= 'cleanfilt_cut.evt'
# FILIN167= 'cleanfilt_cut.evt'
# FILIN168= 'cleanfilt_cut.evt'
# FILIN169= 'cleanfilt_cut.evt'
# FILIN170= 'cleanfilt_cut.evt'
# FILIN171= 'cleanfilt_cut.evt'
# FILIN172= 'cleanfilt_cut.evt'
# FILIN173= 'cleanfilt_cut.evt'
# FILIN174= 'cleanfilt_cut.evt'
# FILIN175= 'cleanfilt_cut.evt'
# FILIN176= 'cleanfilt_cut.evt'
# FILIN177= 'cleanfilt_cut.evt'
# FILIN178= 'cleanfilt_cut.evt'
# FILIN179= 'cleanfilt_cut.evt'
# FILIN180= 'cleanfilt_cut.evt'
# FILIN181= 'cleanfilt_cut.evt'
# FILIN182= 'cleanfilt_cut.evt'
# FILIN183= 'cleanfilt_cut.evt'
# FILIN184= 'cleanfilt_cut.evt'
# FILIN185= 'cleanfilt_cut.evt'
# FILIN186= 'cleanfilt_cut.evt'
# FILIN187= 'cleanfilt_cut.evt'
# FILIN188= 'cleanfilt_cut.evt'
# FILIN189= 'cleanfilt_cut.evt'
# FILIN190= 'cleanfilt_cut.evt'
# FILIN191= 'cleanfilt_cut.evt'
# FILIN192= 'cleanfilt_cut.evt'
# FILIN193= 'cleanfilt_cut.evt'
# FILIN194= 'cleanfilt_cut.evt'
# FILIN195= 'cleanfilt_cut.evt'
# FILIN196= 'cleanfilt_cut.evt'
# FILIN197= 'cleanfilt_cut.evt'
# FILIN198= 'cleanfilt_cut.evt'
# FILIN199= 'cleanfilt_cut.evt'
# FILIN200= 'cleanfilt_cut.evt'
# FILIN201= 'cleanfilt_cut.evt'
# FILIN202= 'cleanfilt_cut.evt'
# FILIN203= 'cleanfilt_cut.evt'
# FILIN204= 'cleanfilt_cut.evt'
# FILIN205= 'cleanfilt_cut.evt'
# FILIN206= 'cleanfilt_cut.evt'
# FILIN207= 'cleanfilt_cut.evt'
# FILIN208= 'cleanfilt_cut.evt'
# FILIN209= 'cleanfilt_cut.evt'
# FILIN210= 'cleanfilt_cut.evt'
# FILIN211= 'cleanfilt_cut.evt'
# FILIN212= 'cleanfilt_cut.evt'
# FILIN213= 'cleanfilt_cut.evt'
# FILIN214= 'cleanfilt_cut.evt'
# FILIN215= 'cleanfilt_cut.evt'
# FILIN216= 'cleanfilt_cut.evt'
# FILIN217= 'cleanfilt_cut.evt'
# FILIN218= 'cleanfilt_cut.evt'
# FILIN219= 'cleanfilt_cut.evt'
# FILIN220= 'cleanfilt_cut.evt'
# FILIN221= 'cleanfilt_cut.evt'
# FILIN222= 'cleanfilt_cut.evt'
# FILIN223= 'cleanfilt_cut.evt'
# FILIN224= 'cleanfilt_cut.evt'
# FILIN225= 'cleanfilt_cut.evt'
# FILIN226= 'cleanfilt_cut.evt'
# FILIN227= 'cleanfilt_cut.evt'
# FILIN228= 'cleanfilt_cut.evt'
# FILIN229= 'cleanfilt_cut.evt'
# FILIN230= 'cleanfilt_cut.evt'
# FILIN231= 'cleanfilt_cut.evt'
# FILIN232= 'cleanfilt_cut.evt'
# FILIN233= 'cleanfilt_cut.evt'
# FILIN234= 'cleanfilt_cut.evt'
# FILIN235= 'cleanfilt_cut.evt'
# FILIN236= 'cleanfilt_cut.evt'
# FILIN237= 'cleanfilt_cut.evt'
# FILIN238= 'cleanfilt_cut.evt'
# FILIN239= 'cleanfilt_cut.evt'
# FILIN240= 'cleanfilt_cut.evt'
# FILIN241= 'cleanfilt_cut.evt'
# FILIN242= 'cleanfilt_cut.evt'
# FILIN243= 'cleanfilt_cut.evt'
# FILIN244= 'cleanfilt_cut.evt'
# FILIN245= 'cleanfilt_cut.evt'
# FILIN246= 'cleanfilt_cut.evt'
# FILIN247= 'cleanfilt_cut.evt'
# FILIN248= 'cleanfilt_cut.evt'
# FILIN249= 'cleanfilt_cut.evt'
# FILIN250= 'cleanfilt_cut.evt'
# FILIN251= 'cleanfilt_cut.evt'
# FILIN252= 'cleanfilt_cut.evt'
# FILIN253= 'cleanfilt_cut.evt'
# FILIN254= 'cleanfilt_cut.evt'
# FILIN255= 'cleanfilt_cut.evt'
# FILIN256= 'cleanfilt_cut.evt'
# FILIN257= 'cleanfilt_cut.evt'
# FILIN258= 'cleanfilt_cut.evt'
# FILIN259= 'cleanfilt_cut.evt'
# FILIN260= 'cleanfilt_cut.evt'
# FILIN261= 'cleanfilt_cut.evt'
# FILIN262= 'cleanfilt_cut.evt'
# FILIN263= 'cleanfilt_cut.evt'
# FILIN264= 'cleanfilt_cut.evt'
# FILIN265= 'cleanfilt_cut.evt'
# FILIN266= 'cleanfilt_cut.evt'
# FILIN267= 'cleanfilt_cut.evt'
# FILIN268= 'cleanfilt_cut.evt'
# FILIN269= 'cleanfilt_cut.evt'
# FILIN270= 'cleanfilt_cut.evt'
# FILIN271= 'cleanfilt_cut.evt'
# FILIN272= 'cleanfilt_cut.evt'
# FILIN273= 'cleanfilt_cut.evt'
# FILIN274= 'cleanfilt_cut.evt'
# FILIN275= 'cleanfilt_cut.evt'
# FILIN276= 'cleanfilt_cut.evt'
# FILIN277= 'cleanfilt_cut.evt'
# FILIN278= 'cleanfilt_cut.evt'
# FILIN279= 'cleanfilt_cut.evt'
# HISTORY CFITSIO used the following filtering expression to create this table:
# HISTORY J0030+0451_sun80_0.25-8.0keV_newgain_thru412_PSR_fixed.evt[PI>=25&&PI<=3
# HISTORY 00]

# %%
data = hdul[1].data

# %%
data.columns
# Out:
# ColDefs(
#     name = 'TIME'; format = '1D'; unit = 's'; disp = 'F20.9'
#     name = 'RAWX'; format = '1B'; unit = 'pixel'; coord_ref_point = 0; coord_ref_value = 0.0; coord_inc = 1.0
#     name = 'RAWY'; format = '1B'; unit = 'pixel'; coord_ref_point = 0; coord_ref_value = 0.0; coord_inc = 1.0
#     name = 'PHA'; format = '1I'; unit = 'chan'; null = -32768
#     name = 'PHA_FAST'; format = '1I'; unit = 'chan'; null = -32768
#     name = 'DET_ID'; format = '1B'; disp = 'I2.2'
#     name = 'DEADTIME'; format = '1B'; unit = 's'; bscale = 6.202e-07; bzero = 3.101e-07; disp = 'F11.9'
#     name = 'EVENT_FLAGS'; format = '8X'
#     name = 'TICK'; format = '1K'
#     name = 'MPU_A_TEMP'; format = 'I'; unit = 'Celsius'; null = -1; bscale = 0.10600843; bzero = -273.42105; disp = 'F6.3'
#     name = 'MPU_UNDER_COUNT'; format = 'J'; null = -1
#     name = 'PI_FAST'; format = '1I'; unit = 'chan'; null = -32768
#     name = 'PI'; format = '1I'; unit = 'chan'; null = -32768
#     name = 'PI_RATIO'; format = '1E'
#     name = 'PULSE_PHASE'; format = 'D'
# )

# %%
plt.figure(figsize=(20,6))
plt.plot(data['TIME'],data['PHA'],'.')
